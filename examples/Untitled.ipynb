# %%
import ilo
import time
ilo.check_robot_on_bluetooth()
# Out:
# ilo robot library version:  0.0.56
# For more information about the library use ilo.info() command line
# For any help or support contact us on our website, ilorobot.com
# [ILO] Scanning for BLE devices...
# +--------------------------------------+-----------+-----------------+
# |            Device adress             | ID of ilo |   Name of ilo   |
# +--------------------------------------+-----------+-----------------+
# | D0BF5829-C5A6-8869-0F56-13628AD90E43 |     1     | ilo_BLE_default |
# +--------------------------------------+-----------+-----------------+
# Use for example: my_ilo = ilo.robot(1) to create an object my_ilo with the ID = 1
# True

# %%
my_ilo = ilo.robot(1)
# Out:
# Your are connected to default
# Checking for online updates... Please wait.
# Failed to check for updates.

# %%
for i in range(10):
    print(my_ilo.step('front', 0.1))
    print(i)
# Out:
# True
# 0
# True
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 for i in range(10):
# ----> 2     print(my_ilo.step('front', 0.1))
#       3     print(i)
#
# File ~/Documents/GitHub/lib-python/base_folderv.0.0.54/libname/ilo.py:1453, in robot.step(self, direction, step, finish_state)
#    1448 timeout = (2.5 * actual_steps) + 3.0
#    1450 # print(f"Waiting for end of movement (timeout: {timeout:.2f}s)...")
#    1451
#    1452 # Wait for the "avp0" frame indicating movement completion
# -> 1453 movement_finished = self._movement_complete.wait(timeout=timeout)
#    1454 return True
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# ...

# %%
my_ilo.set_led_shape('11')

# %%
my_ilo.set_led_color(my_ilo.get_color_card('rgb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_ilo.set_led_color(my_ilo.get_color_card('rgb'))
#
# TypeError: robot.set_led_color() missing 2 required positional arguments: 'green' and 'blue'

# %%
pip install ilo --upgrade
# Out:
# ...
#   Attempting uninstall: ilo
#     Found existing installation: ilo 0.0.55
#     Uninstalling ilo-0.0.55:
#       Successfully uninstalled ilo-0.0.55
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
my_ilo.rotation(90)  # 180 degrés
# Out:
# Sent:     <avpxyr090>
