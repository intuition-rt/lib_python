# %%
import ilo
# Out:
# ilo robot library version  0.31
# For more information about the library use ilo.info() command line
# For any help or support contact us on our website, ilorobot.com
# Looking for ilo on your network ...
# +-------------+-----------+
# |  IP Address | ID of ilo |
# +-------------+-----------+
# | 192.168.4.1 |     1     |
# +-------------+-----------+
#
# Use for exemple: my_ilo = ilo.robot(1) to created object my_ilo with the ID = 1

# %%
ilo.check_ilo_on_network()
# Out:
# Looking for ilo on your network ...
# +-------------+-----------+
# |  IP Address | ID of ilo |
# +-------------+-----------+
# | 192.168.4.1 |     1     |
# +-------------+-----------+
#
# Use for exemple: my_ilo = ilo.robot(1) to created object my_ilo with the ID = 1

# %%
my_ilo = ilo.robot(1)
# Out:
# 192.168.4.1
# Connecting...
# Connected

# %%
my_ilo.step("back")

# %%
my_ilo.stop()

# %%
my_ilo.test_connection()
# Out:
# True

# %%
my_ilo.list_order(["front", "back"])

# %%
#my_ilo.game()

# %%
my_ilo.get_color_clear()
# Out:
# data reçu:    'i11l0m0r0o'
# (0, 0, 0)

# %%
my_ilo.get_color_rgb()
# Out:
# data reçu:    'i10r155g-144b72o'
# ('155', '-144', '72')

# %%
my_ilo.set_led_captor(False)
